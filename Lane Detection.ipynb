# %% [markdown]
# # Ex. No: 07
# ## Lane Detection using Hough Transform.
#
# **Name :** THANUSHREE M    **Reg. No :** 212224240169    **Slot No :** T2-J6

# %%
# Import 
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
# Read Image
img = cv2.imread("lan_img1.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
# Grayscale
gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

# %%
# Display Original and Grayscale
plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
plt.imshow(img)
plt.title("Input Image")
plt.axis("off")

plt.subplot(1,2,2)
plt.imshow(gray, cmap='gray')
plt.title("Grayscale")
plt.axis("off")

plt.show()

# %%
lan_img1edges = cv2.Canny(img, 50, 150)

# %%
plt.figure(figsize=(6,4))
plt.imshow(lan_img1edges, cmap='gray')
plt.title("Edge Detection")
plt.axis("off")
plt.show()

# %%
# Region of Interest
height, width = lan_img1edges.shape

mask = np.zeros_like(lan_img1edges)

polygon = np.array([[
    (50, height),
    (width-50, height),
    (width//2, int(height*0.55))
]], np.int32)

cv2.fillPoly(mask, polygon, 255)

roi = cv2.bitwise_and(lan_img1edges, mask)

plt.figure(figsize=(6,4))
plt.imshow(roi, cmap='gray')
plt.title("ROI Masked Image")
plt.axis("off")
plt.show()

# %%
edges = cv2.Canny(roi, 100, 200)

canny_blur = cv2.GaussianBlur(edges, (5,5), 0)

# %%
lines = cv2.HoughLinesP(
    canny_blur,
    1,
    np.pi/180,
    threshold=30,
    minLineLength=20,
    maxLineGap=10
)

# %%
# Draw Detected Lines
line_image = np.zeros_like(img)

if lines is not None:
    for line in lines:
        x1, y1, x2, y2 = line[0]
        cv2.line(line_image, (x1,y1), (x2,y2), (255,0,0), 3)

plt.figure(figsize=(6,4))
plt.imshow(line_image)
plt.title("Detected Lines")
plt.axis("off")
plt.show()

# %%
# Final Output
final_output = cv2.addWeighted(img, 0.8, line_image, 1, 0)

plt.figure(figsize=(6,4))
plt.imshow(final_output)
plt.title("Final Lane Detection Output")
plt.axis("off")
plt.show()
